# %%
import pandas as pd
df = pd.read_csv('car_prices.csv')

# %%
df.isnull().sum()
# Out:
# year                0
# make              238
# model             240
# trim              423
# body             1680
# transmission     6749
# vin                 0
# state               1
# condition       11793
# odometer           76
# color             143
# interior          143
# seller              1
# mmr                 1
# sellingprice        1
# saledate            1
# dtype: int64

# %%
fill_unknown = ['make', 'model', 'trim', 'body', 'transmission', 'color', 'interior', 'seller']
df[fill_unknown] = df[fill_unknown].fillna('unknown')

# %%
df.isnull().sum()
# Out:
# year                0
# make                0
# model               0
# trim                0
# body                0
# transmission        0
# vin                 0
# state               1
# condition       11794
# odometer           82
# color               0
# interior            0
# seller              0
# mmr                 1
# sellingprice        1
# saledate            1
# dtype: int64

# %%
df['condition'] = df['condition'].fillna(df['condition'].median())
df['odometer'] = df['odometer'].fillna(df['odometer'].median())
df['mmr'] = df['mmr'].fillna(df['mmr'].median())
df['sellingprice'] = df['sellingprice'].fillna(df['sellingprice'].median())

# %%
df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           1
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        1
# dtype: int64

# %%
df['state'] = df['state'].fillna(df['state'].mode()[0])
df['saledate'] = pd.to_datetime(df['saledate'], errors='coerce')
df['saledate'] = df['saledate'].fillna(method='ffill')
# Out:
# <ipython-input-11-db5e7d72133c>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['saledate'] = pd.to_datetime(df['saledate'], errors='coerce')
# <ipython-input-11-db5e7d72133c>:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['saledate'] = pd.to_datetime(df['saledate'], errors='coerce')
# <ipython-input-11-db5e7d72133c>:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['saledate'] = df['saledate'].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
print("✅ Missing values after cleaning:\n")
print(df.isnull().sum())
# Out:
# ✅ Missing values after cleaning:
#
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_')

# %%
df.dtypes
# Out:
# year              int64
# make             object
# model            object
# trim             object
# body             object
# transmission     object
# vin              object
# state            object
# condition       float64
# odometer        float64
# color            object
# interior         object
# seller           object
# mmr             float64
# sellingprice    float64
# saledate         object
# dtype: object

# %%
df['saledate'] = pd.to_datetime(df['saledate'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-24cc194b34ee> in <cell line: 0>()
# ----> 1 df['saledate'] = pd.to_datetime(df['saledate'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     245         unique_dates = unique(arg)
#     246         if len(unique_dates) < len(arg):
# --> 247             cache_dates = convert_listlike(unique_dates, format)
#     248             # GH#45319
#     249             try:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     434
# --> 435     result, tz_parsed = objects_to_datetime64(
#     436         arg,
#     437         dayfirst=dayfirst,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2396     data = np.asarray(data, dtype=np.object_)
#    2397
# -> 2398     result, tz_parsed = tslib.array_to_datetime(
#    2399         data,
#    2400         errors=errors,
#
# tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# strptime.pyx in pandas._libs.tslibs.strptime.DatetimeParseState.process_datetime()
#
# ValueError: Tz-aware datetime.datetime cannot be converted to datetime64 unless utc=True, at position 13

# %%
df['saledate'] = pd.to_datetime(df['saledate'], utc=True)

# %%
df.dtypes
# Out:
# year                          int64
# make                         object
# model                        object
# trim                         object
# body                         object
# transmission                 object
# vin                          object
# state                        object
# condition                   float64
# odometer                    float64
# color                        object
# interior                     object
# seller                       object
# mmr                         float64
# sellingprice                float64
# saledate        datetime64[ns, UTC]
# dtype: object

# %%
df['saledate'] = df['saledate'].dt.tz_localize(None)

# %%
df.dtypes
# Out:
# year                     int64
# make                    object
# model                   object
# trim                    object
# body                    object
# transmission            object
# vin                     object
# state                   object
# condition              float64
# odometer               float64
# color                   object
# interior                object
# seller                  object
# mmr                    float64
# sellingprice           float64
# saledate        datetime64[ns]
# dtype: object

# %%
df
# Out:
#        year   make                model        trim   body transmission  \
# 0      2015    Kia              Sorento          LX    SUV    automatic
# 1      2015    Kia              Sorento          LX    SUV    automatic
# 2      2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3      2015  Volvo                  S60          T5  Sedan    automatic
# 4      2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
# ...     ...    ...                  ...         ...    ...          ...
# 53377  2012    Kia              Sorento          LX    SUV      unknown
# 53378  2012    Kia                 Soul        Base  Wagon       manual
# 53379  2012    Kia              Sorento          LX    SUV    automatic
# 53380  2012    Kia              Sorento          LX    SUV    automatic
# 53381  2012    Kia             Sportage          EX    SUV    automatic
#
#                      vin state  condition  odometer     color interior  \
# 0      5xyktca69fg566472    ca        5.0   16639.0     white    black
# 1      5xyktca69fg561319    ca        5.0    9393.0     white    beige
# 2      wba3c1c51ek116351    ca       45.0    1331.0      gray    black
# 3      yv1612tb4f1310987    ca       41.0   14282.0     white    black
# 4      wba6b2c57ed129731    ca       43.0    2641.0      gray    black
# ...                  ...   ...        ...       ...       ...      ...
# 53377  5xykt4a19cg283592    pa       48.0   37208.0  burgundy    beige
# 53378  kndjt2a54c7748926    tn       37.0   36663.0     black    black
# 53379  5xykt4a6xcg205737    tx       19.0   78495.0     green    black
# 53380  5xykt3a61cg230276    oh       36.0   65239.0  burgundy     gray
# 53381    kndpc3a26c73311    ca       33.0   67565.5   unknown  unknown
#
#                                        seller      mmr  sellingprice  \
# 0                     kia motors america  inc  20500.0       21500.0
# 1                     kia motors america  inc  20800.0       21500.0
# 2      financial services remarketing (lease)  31900.0       30000.0
# 3                     volvo na rep/world omni  27500.0       27750.0
# 4      financial services remarketing (lease)  66000.0       67000.0
# ...                                       ...      ...           ...
# 53377                      kia motors finance  13850.0       14000.0
# 53378                            gm financial   9700.0        9500.0
# 53379                        tdaf remarketing  11200.0       10500.0
# 53380                      jr's auto city inc  11800.0       12400.0
# 53381                                 unknown  10650.0       10200.0
#
#                  saledate
# 0     2014-12-16 04:30:00
# 1     2014-12-16 04:30:00
# 2     2015-01-14 20:30:00
# 3     2015-01-28 20:30:00
# 4     2014-12-18 04:30:00
# ...                   ...
# 53377 2015-01-02 01:00:00
# 53378 2014-12-30 02:30:00
# 53379 2014-12-31 02:15:00
# 53380 2014-12-23 01:30:00
# 53381 2014-12-23 01:30:00
#
# [53382 rows x 16 columns]

# %%
df['saledate'] = pd.to_datetime(df['saledate'], utc=True).dt.tz_localize(None)

# %%
df
# Out:
#        year   make                model        trim   body transmission  \
# 0      2015    Kia              Sorento          LX    SUV    automatic
# 1      2015    Kia              Sorento          LX    SUV    automatic
# 2      2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3      2015  Volvo                  S60          T5  Sedan    automatic
# 4      2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
# ...     ...    ...                  ...         ...    ...          ...
# 53377  2012    Kia              Sorento          LX    SUV      unknown
# 53378  2012    Kia                 Soul        Base  Wagon       manual
# 53379  2012    Kia              Sorento          LX    SUV    automatic
# 53380  2012    Kia              Sorento          LX    SUV    automatic
# 53381  2012    Kia             Sportage          EX    SUV    automatic
#
#                      vin state  condition  odometer     color interior  \
# 0      5xyktca69fg566472    ca        5.0   16639.0     white    black
# 1      5xyktca69fg561319    ca        5.0    9393.0     white    beige
# 2      wba3c1c51ek116351    ca       45.0    1331.0      gray    black
# 3      yv1612tb4f1310987    ca       41.0   14282.0     white    black
# 4      wba6b2c57ed129731    ca       43.0    2641.0      gray    black
# ...                  ...   ...        ...       ...       ...      ...
# 53377  5xykt4a19cg283592    pa       48.0   37208.0  burgundy    beige
# 53378  kndjt2a54c7748926    tn       37.0   36663.0     black    black
# 53379  5xykt4a6xcg205737    tx       19.0   78495.0     green    black
# 53380  5xykt3a61cg230276    oh       36.0   65239.0  burgundy     gray
# 53381    kndpc3a26c73311    ca       33.0   67565.5   unknown  unknown
#
#                                        seller      mmr  sellingprice  \
# 0                     kia motors america  inc  20500.0       21500.0
# 1                     kia motors america  inc  20800.0       21500.0
# 2      financial services remarketing (lease)  31900.0       30000.0
# 3                     volvo na rep/world omni  27500.0       27750.0
# 4      financial services remarketing (lease)  66000.0       67000.0
# ...                                       ...      ...           ...
# 53377                      kia motors finance  13850.0       14000.0
# 53378                            gm financial   9700.0        9500.0
# 53379                        tdaf remarketing  11200.0       10500.0
# 53380                      jr's auto city inc  11800.0       12400.0
# 53381                                 unknown  10650.0       10200.0
#
#                  saledate
# 0     2014-12-16 04:30:00
# 1     2014-12-16 04:30:00
# 2     2015-01-14 20:30:00
# 3     2015-01-28 20:30:00
# 4     2014-12-18 04:30:00
# ...                   ...
# 53377 2015-01-02 01:00:00
# 53378 2014-12-30 02:30:00
# 53379 2014-12-31 02:15:00
# 53380 2014-12-23 01:30:00
# 53381 2014-12-23 01:30:00
#
# [53382 rows x 16 columns]

# %%
df['saledate'] = df['saledate'].dt.strftime('%d-%m-%Y')

# %%
df
# Out:
#        year   make                model        trim   body transmission  \
# 0      2015    Kia              Sorento          LX    SUV    automatic
# 1      2015    Kia              Sorento          LX    SUV    automatic
# 2      2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3      2015  Volvo                  S60          T5  Sedan    automatic
# 4      2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
# ...     ...    ...                  ...         ...    ...          ...
# 53377  2012    Kia              Sorento          LX    SUV      unknown
# 53378  2012    Kia                 Soul        Base  Wagon       manual
# 53379  2012    Kia              Sorento          LX    SUV    automatic
# 53380  2012    Kia              Sorento          LX    SUV    automatic
# 53381  2012    Kia             Sportage          EX    SUV    automatic
#
#                      vin state  condition  odometer     color interior  \
# 0      5xyktca69fg566472    ca        5.0   16639.0     white    black
# 1      5xyktca69fg561319    ca        5.0    9393.0     white    beige
# 2      wba3c1c51ek116351    ca       45.0    1331.0      gray    black
# 3      yv1612tb4f1310987    ca       41.0   14282.0     white    black
# 4      wba6b2c57ed129731    ca       43.0    2641.0      gray    black
# ...                  ...   ...        ...       ...       ...      ...
# 53377  5xykt4a19cg283592    pa       48.0   37208.0  burgundy    beige
# 53378  kndjt2a54c7748926    tn       37.0   36663.0     black    black
# 53379  5xykt4a6xcg205737    tx       19.0   78495.0     green    black
# 53380  5xykt3a61cg230276    oh       36.0   65239.0  burgundy     gray
# 53381    kndpc3a26c73311    ca       33.0   67565.5   unknown  unknown
#
#                                        seller      mmr  sellingprice  \
# 0                     kia motors america  inc  20500.0       21500.0
# 1                     kia motors america  inc  20800.0       21500.0
# 2      financial services remarketing (lease)  31900.0       30000.0
# 3                     volvo na rep/world omni  27500.0       27750.0
# 4      financial services remarketing (lease)  66000.0       67000.0
# ...                                       ...      ...           ...
# 53377                      kia motors finance  13850.0       14000.0
# 53378                            gm financial   9700.0        9500.0
# 53379                        tdaf remarketing  11200.0       10500.0
# 53380                      jr's auto city inc  11800.0       12400.0
# 53381                                 unknown  10650.0       10200.0
#
#          saledate
# 0      16-12-2014
# 1      16-12-2014
# 2      14-01-2015
# 3      28-01-2015
# 4      18-12-2014
# ...           ...
# 53377  02-01-2015
# 53378  30-12-2014
# 53379  31-12-2014
# 53380  23-12-2014
# 53381  23-12-2014
#
# [53382 rows x 16 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [year, make, model, trim, body, transmission, vin, state, condition, odometer, color, interior, seller, mmr, sellingprice, saledate]
# Index: []
